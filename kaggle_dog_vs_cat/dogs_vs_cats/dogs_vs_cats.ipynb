# %%
#enable gpu
# !nvidia-smi
# Out:
# Wed Sep 16 01:53:46 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /root/.keras/keras.json
# Out:
# {
#     "epsilon": 1e-07,
#     "floatx": "float32",
#     "image_data_format": "channels_last",
#     "backend": "tensorflow"
# }

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# next, add the location of the file to the path:
import sys
sys.path.append('/content/drive/Shared drives/kaid/DL/kaggle_dog_vs_cat/dogs_vs_cats')
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/Shared drives/kaid/DL/kaggle_dog_vs_cat/dogs_vs_cats']

# %%
# %cd '/content/drive/Shared drives/kaid/DL/kaggle_dog_vs_cat/dogs_vs_cats'
# !ls
# Out:
# /content/drive/Shared drives/kaid/DL/kaggle_dog_vs_cat/dogs_vs_cats
# build_dogs_vs_cats.py  crop_accuracy.py  pyimagesearch	train_alexnet.py
# config		       output		 test.py

# %%
# !python3 build_dogs_vs_cats.py

# %%
# !python3 train_alexnet.py

# %%
# !python3 crop_accuracy.py

# %%
# !python3 extract_features.py --dataset ../datasets/kaggle_dogs_vs_cats/train --output ../datasets/kaggle_dogs_vs_cats/hdf5/features.hdf5
